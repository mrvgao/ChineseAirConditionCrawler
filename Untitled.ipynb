# %%
import pandas as pd

# %%
dataframe = pd.read_csv('air_condition.csv')

# %%
beijing = dataframe[(dataframe['city'] == 'beijing')]

# %%
nanjing = dataframe[(dataframe['city']) == 'nanjing']

# %%
beijing
# Out:
#           city          日期  质量等级  AQI指数  当天AQI排名  PM2.5  PM10  No2  So2    Co  \
# 35699  beijing  2013-10-28  严重污染    306      106    255   277  105   30  2.60
# 35700  beijing  2013-10-29     良     62       22     39    62   46   10  0.91
# 35701  beijing  2013-10-30     良     99       61     71   101   72   11  1.18
# 35702  beijing  2013-10-31  中度污染    176       98    135   162   96   10  1.62
# 35703  beijing  2013-11-01  重度污染    231      102    181   202  100   14  1.89
# 35704  beijing  2013-11-02  严重污染    294      112    243   253  104   11  2.14
# 35705  beijing  2013-11-03     良     80       36     53    82   45    5  0.82
# 35706  beijing  2013-11-04     良     57       11     36    60   54    9  0.87
# 35707  beijing  2013-11-05  中度污染    184      109    143   188   95   23  2.06
# 35708  beijing  2013-11-06  中度污染    189      100     91   135   55    9  1.47
# 35709  beijing  2013-11-07     良     59        4     32    55   42    9  0.35
# ...

# %%
nanjing
# Out:
#           city          日期  质量等级  AQI指数  当天AQI排名  PM2.5  PM10  No2  So2    Co  \
# 39037  nanjing  2013-10-28  中度污染    169       75    129   223   86   46  1.23
# 39038  nanjing  2013-10-29  重度污染    203       88    157   284  134   47  1.53
# 39039  nanjing  2013-10-30  轻度污染    120       78     90   148   64   22  0.83
# 39040  nanjing  2013-10-31  轻度污染    107       65     80   121   54   18  1.02
# 39041  nanjing  2013-11-01     良     91       49     67   123   71   26  0.87
# 39042  nanjing  2013-11-02  轻度污染    141       75    106   179   63   24  0.93
# 39043  nanjing  2013-11-03  轻度污染    142       85    108   167   48   16  1.37
# 39044  nanjing  2013-11-04  轻度污染    133       96     96   169   69   25  1.11
# 39045  nanjing  2013-11-05     良     83       41     57   112   70   29  0.87
# 39046  nanjing  2013-11-06  轻度污染    141       73    107   194   93   21  1.33
# 39047  nanjing  2013-11-07  中度污染    166       97    143   254  119   35  1.26
# ...

# %%
scatter_matrix(nanjing)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10c7f19e8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f773cc0>]], dtype=object)

# %%
nanjing_pm25 = nanjing['pm2.5']
# Out:
# 35699   NaN
# 35700   NaN
# 35701   NaN
# 35702   NaN
# 35703   NaN
# 35704   NaN
# 35705   NaN
# 35706   NaN
# 35707   NaN
# 35708   NaN
# 35709   NaN
# 35710   NaN
# 35711   NaN
# 35712   NaN
# 35713   NaN
# 35714   NaN
# 35715   NaN
# 35716   NaN
# 35717   NaN
# 35718   NaN
# 35719   NaN
# 35720   NaN
# 35721   NaN
# 35722   NaN
# 35723   NaN
# 35724   NaN
# 35725   NaN
# 35726   NaN
# 35727   NaN
# 35728   NaN
#          ..
# 40232   NaN
# 40233   NaN
# 40234   NaN
# 40235   NaN
# 40236   NaN
# 40237   NaN
# 40238   NaN
# 40239   NaN
# 40240   NaN
# 40241   NaN
# 40242   NaN
# 40243   NaN
# 40244   NaN
# 40245   NaN
# 40246   NaN
# 40247   NaN
# 40248   NaN
# 40249   NaN
# 40250   NaN
# 40251   NaN
# 40252   NaN
# 40253   NaN
# 40254   NaN
# 40255   NaN
# 40256   NaN
# 40257   NaN
# 40258   NaN
# 40259   NaN
# 40260   NaN
# 40261   NaN
# dtype: float64

# %%
from pandas.tools.plotting import scatter_matrix

# %%
scatter_matrix(beijing)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11227c588>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1160de5c0>]], dtype=object)

# %%
# %matplotlib inline
beijing.plot()

# %%
beijing_pm2 = beijing['PM2.5']

# %%
nanjing_pm2 = nanjing['PM2.5']

# %%
import matplotlib.pyplot as plt

# %%
plt.plot( range(len(beijing_pm2)), beijing_pm2, range(len(nanjing_pm2)), nanjing_pm2)

# %%
nanjing_pm2.plot()

# %%
beijing_pm2.plot()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()

# %%
beijing_pm2.hist(bins=20)
